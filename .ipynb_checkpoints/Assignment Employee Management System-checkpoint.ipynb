# %%
dict_employee = {}

# %%
dict_employee = {'1': {'id': '1', 'name': 'Jawwad', 'type': 'Staff', 'age': '27', 'status': 'Married', 'kids': '0', 'years': '2019'}, '2': {'id': '2', 'name': 'Arsalan', 'type': 'Staff', 'age': '22', 'status': 'Married', 'kids': '0', 'years': '2018'}, '3': {'id': '3', 'name': 'Hina', 'type': 'Officer', 'age': '28', 'status': 'Single', 'kids': '0', 'years': '2016'}, '4': {'id': '4', 'name': 'Isra', 'type': 'Staff', 'age': '28', 'status': 'Marrried', 'kids': '1', 'years': '2011'}, '5': {'id': '5', 'name': 'Faizan', 'type': 'Officer', 'age': '33', 'status': 'Single', 'kids': '0', 'years': '2008'}, '6': {'id': '6', 'name': 'Ammar', 'type': 'Officer', 'age': '32', 'status': 'Married', 'kids': '2', 'years': '2008'}, '7': {'id': '7', 'name': 'Atta', 'type': 'Officer', 'age': '36', 'status': 'Married', 'kids': '2', 'years': '2004'}, '8': {'id': '8', 'name': 'Sadam', 'type': 'Officer', 'age': '32', 'status': 'Married', 'kids': '1', 'years': '2019'}, '9': {'id': '9', 'name': 'Junaid', 'type': 'Officer', 'age': '25', 'status': 'Single', 'kids': '0', 'years': '2019'}, '10': {'id': '10', 'name': 'Asad', 'type': 'Officer', 'age': '27', 'status': 'Single', 'kids': '0', 'years': '2020'}, '11': {'id': '11', 'name': 'Rafiq', 'type': 'Staff', 'age': '35', 'status': 'Single', 'kids': '0', 'years': '2008'}, '12': {'id': '12', 'name': 'Fahad', 'type': 'Staff', 'age': '33', 'status': 'Married', 'kids': '3', 'years': '2015'}}

# %%
# Employee Creation
def Employee_Creation():
    employee_id = input('Enter employee id: ')
    employee_name = input('Enter employee name: ')
    employee_type = input('Enter employee type: ')
    employee_age = input('Enter employee age: ')
    employee_status = input('Enter employee status: ')
    employee_kids = input('Enter employee kids: ')
    employee_years = input('Enter employee years: ')
  
    employee_data = {}
    employee_data['id'] = employee_id.title()
    employee_data['name'] = employee_name.title()
    employee_data['type'] = employee_type.title()
    employee_data['age'] = employee_age.title()
    employee_data['status'] = employee_status.title()
    employee_data['kids'] = employee_kids.title()
    employee_data['years'] = employee_years.title()
    dict_employee[employee_id]= employee_data
    print(dict_employee)

# %%
def Employee_Updation():
    update_data = input('Enter Employee id: ')
    try:
        employee_id = update_data
        employee_name = input('Enter employee name: ')
        employee_type = input('Enter employee type: ')
        employee_age = input('Enter employee age: ')
        employee_status = input('Enter employee status: ')
        employee_kids = input('Enter employee kids: ')
        employee_years = input('Enter employee years: ')
        dict_employee[employee_id]['id']= employee_id.title()
        dict_employee[employee_id]['name']= employee_name.title()
        dict_employee[employee_id]['type']= employee_type.title()
        dict_employee[employee_id]['age']= employee_age.title()
        dict_employee[employee_id]['status']= employee_status.title()
        dict_employee[employee_id]['kids']= employee_kids.title()
        dict_employee[employee_id]['years']= employee_years.title()
    except:
        print('\nRecord not found\n')

# %%
def Employee_Deletion():
    del_data = input('Enter Employee id: ')
    try:
        del dict_employee[del_data]
        print(dict_employee)
    except:
        print('\nRecord not found\n')

# %%
def Ask_User():
    i = ''
    while i != '1':
        print('Press 1 to enter a new employee record.')
        print('Press 2 to update an existing record.')
        print('Press 3 to search from the employee records.')
        print('Press 4 to remove a record.')
        print('Press q to exit the program.')
        print('\n')
        i = input('Press any key: ')
        if i == '1'or i == '2' or i == '3' or i == '4' or i == 'q':
            return i
        else:
            print('Invalid Input\n')

# %%
def Ask_User_to_continue():
    i = ''
    while i != '1':
        print('\n')
        print('Press 1 to enter a new employee')
        print('Press a to exit this feature')
        print('\n')
        i = input('Press any key: ')
        if i == '1' or i == 'a':
            return i
        else:
            print('\nInvalid Input\n')

# %%
def Employee_Search():
    print('Press 1 to search using the type of employees')
    print('Press 2 to search using an employee_id.')
    print('Press 3 to search using the age.')
    print('Press 4 to search using the status.')
    user = input('Press any key: ')
    try:
        if user  == '1':
            user_search = input('Please search: ')
            for i in dict_employee:
                if dict_employee[i]['type'] == user_search.title():
                    print(dict_employee[i])
        elif user  == '2':
            user_search = input('Please search: ')
            for i in dict_employee:
                if dict_employee[i]['id'] == user_search.title():
                    print(dict_employee[i])
        elif user  == '3':
            user_search = input('Please search: ')
            for i in dict_employee:
                if dict_employee[i]['age'] == user_search.title():
                    print(dict_employee[i])
        elif user  == '4':
            user_search = input('Please search: ')
            for i in dict_employee:
                if dict_employee[i]['status'] == user_search.title():
                    print(dict_employee[i])
        else:
            print('\nInvalid Input\n')
    except:
        print('\nInvalid Entry\n')

# %%
print('*************Employee Management System*************')
print('\n')
i = ''
j = ''
while i != 'q':
    if i == '1':
        while j != 'a':
            Employee_Creation()
            j = Ask_User_to_continue()
        j = ''
    if i == '2':
        while j != 'a':
            Employee_Updation()
            j = Ask_User_to_continue()
        j = ''
    if i == '3':
        while j != 'a':
            Employee_Search()
            j = Ask_User_to_continue()
        j = ''
    if i == '4':
        while j != 'a':
            Employee_Deletion()
            j = Ask_User_to_continue()
        j = ''
    i = Ask_User()
print('Program has been terminated')
# Out:
# *************Employee Management System*************
#
#
# Press 1 to enter a new employee record.
# Press 2 to update an existing record.
# Press 3 to search from the employee records.
# Press 4 to remove a record.
# Press q to exit the program.
#
#
# Press any key: 3
# Press 1 to search using the type of employees
# Press 2 to search using an employee_id.
# Press 3 to search using the age.
# Press 4 to search using the status.
# Press any key: 1
# Please search: 50
#
#
# Press 1 to enter a new employee
# Press a to exit this feature
#
#
# Press any key: 1
# Press 1 to search using the type of employees
# Press 2 to search using an employee_id.
# Press 3 to search using the age.
# Press 4 to search using the status.
# Press any key: 2
# Please search: 50
#
#
# Press 1 to enter a new employee
# Press a to exit this feature
#
#
# Press any key: a
# Press 1 to enter a new employee record.
# Press 2 to update an existing record.
# Press 3 to search from the employee records.
# ...
